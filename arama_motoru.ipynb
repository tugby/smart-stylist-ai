# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# %pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import util

# %%
df = pd.read_csv('articles.csv', nrows=10000)

# %%
secilen_sutunlar = ['article_id', 'prod_name', 'product_group_name', 'colour_group_name', 'detail_desc']
df = df[secilen_sutunlar].dropna()

# %%
df.head()
# Out:
#    article_id          prod_name  product_group_name colour_group_name  \
# 0   108775015          Strap top  Garment Upper body             Black
# 1   108775044          Strap top  Garment Upper body             White
# 2   108775051      Strap top (1)  Garment Upper body         Off White
# 3   110065001  OP T-shirt (Idro)           Underwear             Black
# 4   110065002  OP T-shirt (Idro)           Underwear             White
#
#                                          detail_desc
# 0            Jersey top with narrow shoulder straps.
# 1            Jersey top with narrow shoulder straps.
# 2            Jersey top with narrow shoulder straps.
# 3  Microfibre T-shirt bra with underwired, moulde...
# 4  Microfibre T-shirt bra with underwired, moulde...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

aciklamalar = df['detail_desc'].tolist()

vektorler = model.encode(aciklamalar, show_progress_bar=True)
# Out:
# ...
# Batches:   0%|          | 0/311 [00:00<?, ?it/s]

# %%
from sentence_transformers import util
import torch

arama_metni = "a tshirt for summer"

arama_vektoru = model.encode(arama_metni)

benzerlik_skorlari = util.cos_sim(arama_vektoru, vektorler)[0]

en_iyi_5_indeks = torch.topk(benzerlik_skorlari, k=5).indices.tolist()

print(f"Senin Araman: '{arama_metni}'\n")
print("İşte senin için bulduğum en uygun 5 ürün:\n")
print("=" * 60)

for i in en_iyi_5_indeks:
    urun_adi = df.iloc[i]['prod_name']
    kategori = df.iloc[i]['product_group_name']
    aciklama = df.iloc[i]['detail_desc']
    
    print(f"👚 Ürün: {urun_adi} ({kategori})")
    print(f"📝 Açıklama: {aciklama}\n")
    print("-" * 60)
# Out:
# Senin Araman: 'a tshirt for summer'
#
# İşte senin için bulduğum en uygun 5 ürün:
#
# ...
# 👚 Ürün: Perfect tee (Garment Upper body)
# 📝 Açıklama: T-shirt in soft, printed cotton jersey.
#
# ------------------------------------------------------------
# 👚 Ürün: T-Shirt Allington R-neck (Garment Upper body)
# 📝 Açıklama: T-shirt in premium cotton jersey.
#
# ------------------------------------------------------------
# 👚 Ürün: R-neck Allington (Garment Upper body)
# 📝 Açıklama: T-shirt in premium cotton jersey.
#
# ------------------------------------------------------------
# 👚 Ürün: R-neck Allington (Garment Upper body)
# 📝 Açıklama: T-shirt in premium cotton jersey.
#
# ------------------------------------------------------------
# 👚 Ürün: R-neck Allington (Garment Upper body)
# 📝 Açıklama: T-shirt in premium cotton jersey.
#
# ------------------------------------------------------------
